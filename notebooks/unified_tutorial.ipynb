# %% [markdown]
# # FunctorFlow Tutorial Library: unified
#
# This notebook was generated from the FunctorFlow tutorial-library layer.
#
# - Library: `unified`
# - Macros: `basket_rocket_pipeline, basket_workflow, completion, db_square, democritus_gluing, gt_neighborhood, ket, rocket_repair, structured_lm_duality`
# - Adapter libraries: `standard`
#
# The goal is to give the ICML tutorial a directly runnable path from packaged
# library concepts to actual FunctorFlow diagrams.

# %%
from pathlib import Path
import sys

def _bootstrap_functorflow() -> Path:
    cwd = Path.cwd().resolve()
    candidates = [cwd, *cwd.parents]
    for candidate in candidates:
        package_root = candidate / "FunctorFlow"
        if (package_root / "__init__.py").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError(
        "Could not find the FunctorFlow package. Run this notebook from the repo "
        "root or from FunctorFlow/notebooks."
    )

REPO_ROOT = _bootstrap_functorflow()
print(f"FunctorFlow repo root: {REPO_ROOT}")

# %%
from FunctorFlow import get_tutorial_library

tutorial = get_tutorial_library("unified")
tutorial.name, tutorial.macro_names, tutorial.adapter_library_names

# %% [markdown]
# ## Macro: `basket_rocket_pipeline`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("basket_rocket_pipeline")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `basket_workflow`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("basket_workflow")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `completion`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("completion")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `db_square`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("db_square")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `democritus_gluing`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("democritus_gluing")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `gt_neighborhood`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("gt_neighborhood")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `ket`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("ket")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `rocket_repair`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("rocket_repair")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Macro: `structured_lm_duality`
#
# Build the diagram from the tutorial library and inspect the exposed ports.

# %%
diagram = tutorial.build_macro("structured_lm_duality")
print(diagram.summary())
{name: (port.ref, port.port_type, port.direction) for name, port in diagram.ports.items()}

# %% [markdown]
# ## Next Step
#
# Use one of these blocks as the seed for a larger composed tutorial path, or
# adapt the generated notebook into a worked ICML example.
